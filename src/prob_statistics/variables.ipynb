# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
url = "./data/nhanes_2015_2016.csv"
da = pd.read_csv(url)

# %%
gender = da["RIAGENDR"]
gender.value_counts()
# Out:
# RIAGENDR
# 2    2976
# 1    2759
# Name: count, dtype: int64

# %%
gender.value_counts().plot(kind="bar")
plt.show()

# %%
gender.value_counts().plot(kind="bar")
plt.xticks([0, 1], ["Male", "Female"])
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %%
# Most common Value
sizes = np.array([22,23,29,32,42,42,42,42,42])

# %%
sizes.mean()
# Out:
# 35.111111111111114

# %%
from scipy import stats
stats.mode(sizes)
# Out:
# ModeResult(mode=42, count=5)

# %%
gender.mode()
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
stats.mode(gender)
# Out:
# ModeResult(mode=2, count=2976)

# %%
# More than one "Clases"
da["HIQ210"]
# Out:
# 0       2.0
# 1       NaN
# 2       2.0
# 3       2.0
# 4       2.0
#        ...
# 5730    2.0
# 5731    2.0
# 5732    2.0
# 5733    2.0
# 5734    2.0
# Name: HIQ210, Length: 5735, dtype: float64

# %%
da["HIQ210"].unique()
# Out:
# array([ 2., nan,  1.,  9.])

# %%
da["HIQ210"].value_counts().plot(kind="bar")
plt.show()

# %%
da["HIQ210"].value_counts().plot(kind="pie")
plt.show()

# %%
# Studying Real-Valued numbers
wt = da["BMXWT"]

# %%
wt
# Out:
# 0        94.8
# 1        90.4
# 2        83.4
# 3       109.8
# 4        55.2
#         ...
# 5730     59.1
# 5731    112.1
# 5732     71.7
# 5733     78.2
# 5734     58.3
# Name: BMXWT, Length: 5735, dtype: float64

# %%
wt.value_counts().plot(kind="bar")
plt.show()

# %%
# wt.hist(bins=2)
wt.hist(bins=20)
plt.show()

# %%
# Custom Matplotlib Histogram
plt.hist(wt, bins=10)
plt.ylabel("Frequency")
plt.xlabel("Weights")
plt.title("Histogram of weights in NHANES Dataset")
plt.show()

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")

# %%
sns.displot(wt, bins=20, kde=True)
sns.despine(offset=10, trim=True)
plt.show()

# %%
# Cetral Tendency
plt.figure(figsize=(20, 5))

x = range(da["BMXWT"].size)
y = da["BMXWT"]

plt.scatter(x, y, marker="x", s=0.5)

plt.title("Weights of individuals")
plt.xlabel("Id of indi")
plt.ylabel("weight (kg)")


p1 = [0, 75]
p2 = [5500, 75]
x_c, y_c = zip(p1, p2)
print(x_c,y_c)
plt.plot(x_c, y_c, color="red", linewidth=0.5)
# Out:
# (0, 5500) (75, 75)

# %%
wt.mean()
# Out:
# 81.34267560889516

# %%
plt.figure(figsize=(10, 5))
x = range(da["BMXWT"].size)
y = da["BMXWT"]

plt.scatter(x, y, marker="x", s=0.5)

plt.title("Weights of individuals")
plt.xlabel("Id of indi")
plt.ylabel("weight (kg)")


x_c, y_c = ([0, 6000], [75, 75])
plt.plot(x_c, y_c, color="red", linewidth=0.75)

x_c, y_c = ([0, 6000], [wt.mean(), wt.mean()])
plt.plot(x_c, y_c, color="green", linewidth=0.75)

# %%
# Box-Plot
